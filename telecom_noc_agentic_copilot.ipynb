# %% [markdown]
# # Telecom NOC Agentic Copilot
# This notebook runs the synthetic data generator, root cause engine, and LangGraph workflow.

# %%
from pathlib import Path
from app.data_generation import build_demo_assets
from app.engine import run_root_cause_engine
from app.agents import run_workflow

data_dir = Path('data')
assets = build_demo_assets(str(data_dir))
assets
# Out:
# {'alarm_path': 'data\\alarm_logs.csv',
#  'topology_path': 'data\\network_topology.jpg',
#  'manual_pdf': 'data\\solution_manual.pdf',
#  'manual_text': 'data\\solution_manual.txt',
#  'defect_log': 'data\\defect_log.csv'}

# %%
engine_output = run_root_cause_engine(assets['alarm_path'], output_dir=str(data_dir))
engine_output['top_candidates']
# Out:
# [{'alarm_id': 'ALM-0003',
#   'alarm_name': 'Fiber Cut',
#   'equipment': 'Edge Router',
#   'timestamp': '2026-06-09 20:00:01',
#   'severity': 'Critical',
#   'score': 5.477},
#  {'alarm_id': 'ALM-0004',
#   'alarm_name': 'Fiber Cut',
#   'equipment': 'Edge Router',
#   'timestamp': '2026-06-09 20:00:02',
#   'severity': 'Critical',
#   'score': 5.462}]

# %%
workflow_result = run_workflow(assets['alarm_path'], approval='Approve')
workflow_result
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3096.47it/s]
# {'alarm_path': 'data\\alarm_logs.csv',
#  'topology_path': 'data\\network_topology.jpg',
#  'graph_path': 'data\\root_cause_subgraph.jpg',
#  'root_cause_output': {'root_cause': 'Fiber Cut',
#   'confidence': 0.95,
#   'affected_equipment': ['Edge Router'],
#   'reasoning': 'The alarm graph indicates a high-weight fiber-related event that explains downstream link and service alarms.',
#   'impact': 'Primary fiber segment and downstream transport services impacted'},
#  'remediation_output': {'root_cause': 'Fiber Cut',
#   'fix': 'Page 1: Fiber Cut\nRoot Cause: Backhoe damage or cable sheath breach on the primary feeder path\nTroubleshooting: Check optical power levels, inspect last-mile route, verify OTDR traces\nFix Procedure: Dispatch field crew, replace damaged fiber, restore service and re-test path\nResolution Category: Major Fix\n Page 2: Router CPU High\nRoot Cause: Unexpected traffic spike or process leak on the edge router\nTroubleshooting: Inspect process utilization, queue depth, and interface counters\nFix Procedure: Reboot the router or clear the misbehaving process\nResolution Category: Minor Fix\n Page 3: Interface Down\nRoot Cause: Physical disconnect or line protocol flap\nTroubleshooting: Verify cable status, optical levels, and port admin state\nFix Procedure: Reset the interface and validate link restoration',
#   'complexity': 'MAJOR',
#   'confidence': 0.88},
#  'issue_class': 'MAJOR',
#  'approval': 'Approve',
#  'ticket_id': 'TKT-019'}
